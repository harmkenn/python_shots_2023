# %% [markdown]
# You can use the formula below to calculate the coordinates of the unknown point given the bearing and distance from a known point 1:
#
# la2 = asin(sin(la1)*cos(d/R) + cos(la1)*sin(d/R)*cos(θ))
#
# lo2 = lo1 + atan2(sin(θ)*sin(d/R)*cos(la1), cos(d/R)−sin(la1)*sin(la2))
#
# Where:
#
# la1 is the latitude of the known point in radians.
# lo1 is the longitude of the known point in radians.
# d is the distance between the two points in km.
# R is the radius of the Earth in km (mean radius = 6,371km).
# θ is the bearing in radians (clockwise from north).

# %%
import numpy as np

# Toronto
latT = 43.67973
lonT = -79.62273
# Agadir
latA = 30.42775
lonA = -9.59811
#Toronto to Agadir
dist = 6212043.0 #meters
Azimuth = 78.64 # degrees

Edist = dist / 1000 / 6371 # distance in earth radii
Azimuthr = Azimuth * np.pi / 180 # Azimuth in radians

latAr = latA * np.pi / 180 
lonAr = lonA * np.pi / 180

lat1 = np.arcsin(np.sin(latAr) * np.cos(Edist) + np.cos(latAr) * np.sin(Edist) * np.cos(Azimuthr)) 
latTc = lat1 *180/np.pi
latTc
#latTc =  asin(sin(lat2) * cos(d/R) - cos(lat2) * sin(d/R) * cos(θ))
# Out:
# 25.13598161842719

# %%
from geopy.distance import geodesic
newport_ri = (43.67973, -79.62273)
cleveland_oh = (30.42775, -9.59811)
print(geodesic(newport_ri, cleveland_oh))

# %% [markdown]
# https://pyproj4.github.io/pyproj/stable/api/geod.html#pyproj.Geod.__init__

# %%
import pyproj
geodesic = pyproj.Geod(ellps='WGS84')
fwd_azimuth,back_azimuth,distance = geodesic.inv(-79.62273,43.67973, -9.59811, 30.42775)
print(fwd_azimuth,back_azimuth,distance)

# %%
endlon, endlat, backaz = geodesic.fwd(-79.62273,43.67973, fwd_azimuth, distance)
print(endlon, endlat, backaz)

# %% [markdown]
# https://theskylive.com/where-is-mercury
#
# https://theskylive.com/planetarium#ra|7.879033694754804|dec|-7.5753095002191815|fov|68

# %%
import pyproj 

geodesic = pyproj.Geod(ellps='WGS84')
P1az = 70.9
alt1 = 60.2 
P2lat = 20.59368
P2lon = 78.96287
P2az = P1az + 180
endlon, endlat, backaz = geodesic.fwd(P2lon,P2lat,P2az,dist) 
print(endlon, endlat, backaz)
for i in range(1, 200):
    P2az = P1az - backaz + P2az
    endlon, endlat, backaz = geodesic.fwd(P2lon,P2lat,P2az,dist)
    if backaz < 0: backaz = backaz + 360
print(endlon, endlat, backaz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       7 P2lon = 78.96287
#       8 P2az = P1az + 180
# ----> 9 endlon, endlat, backaz = geodesic.fwd(P2lon,P2lat,P2az,dist)
#      10 print(endlon, endlat, backaz)
#      11 for i in range(1, 200):
#
# NameError: name 'dist' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def generate_sphere(center, radius, num_points=100):
    theta = np.linspace(0, 2 * np.pi, num_points)
    phi = np.linspace(0, np.pi, num_points)
    theta, phi = np.meshgrid(theta, phi)

    x = center[0] + radius * np.sin(phi) * np.cos(theta)
    y = center[1] + radius * np.sin(phi) * np.sin(theta)
    z = center[2] + radius * np.cos(phi)

    return x, y, z

# Sphere 1
center1 = (0, 0, 0)
radius1 = 1.0
x1, y1, z1 = generate_sphere(center1, radius1)

# Sphere 2
center2 = (1, 0, 0)
radius2 = 1.0
x2, y2, z2 = generate_sphere(center2, radius2)

# Sphere 3
center3 = (0.5, 0.866, 0)
radius3 = 1.0
x3, y3, z3 = generate_sphere(center3, radius3)

# Sphere 4
center4 = (0.5, 0.288, 0.816)
radius4 = 1.0
x4, y4, z4 = generate_sphere(center4, radius4)

# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the spheres
ax.plot_surface(x1, y1, z1, color='r', alpha=0.5)
ax.plot_surface(x2, y2, z2, color='g', alpha=0.5)
ax.plot_surface(x3, y3, z3, color='b', alpha=0.5)
ax.plot_surface(x4, y4, z4, color='y', alpha=0.5)

# Set plot limits and labels
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_zlim(-2, 2)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def plot_sphere_intersecting_earth(center, radius):
    # Create a 3D plot
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    # Plot the Earth's surface as a sphere
    earth_radius = 6371.0  # Approximate Earth's radius in km
    phi = np.linspace(0, 2 * np.pi, 100)
    theta = np.linspace(0, np.pi, 100)
    phi, theta = np.meshgrid(phi, theta)
    x_earth = earth_radius * np.sin(theta) * np.cos(phi)
    y_earth = earth_radius * np.sin(theta) * np.sin(phi)
    z_earth = earth_radius * np.cos(theta)
    ax.plot_surface(x_earth, y_earth, z_earth, color='lightblue', alpha=0.8)

    # Plot the sphere intersecting the Earth
    phi = np.linspace(0, 2 * np.pi, 100)
    theta = np.linspace(0, np.pi/2, 100)
    phi, theta = np.meshgrid(phi, theta)
    x_sphere = center[0] + radius * np.sin(theta) * np.cos(phi)
    y_sphere = center[1] + radius * np.sin(theta) * np.sin(phi)
    z_sphere = center[2] + radius * np.cos(theta)
    ax.plot_surface(x_sphere, y_sphere, z_sphere, color='red', alpha=0.6)

    # Set plot limits and labels
    ax.set_xlim(-earth_radius, earth_radius)
    ax.set_ylim(-earth_radius, earth_radius)
    ax.set_zlim(-earth_radius, earth_radius)
    ax.set_xlabel('X (km)')
    ax.set_ylabel('Y (km)')
    ax.set_zlabel('Z (km)')

    # Set plot title
    plt.title('Sphere Intersecting with Earth')

    # Show the plot
    plt.show()

# Sphere center (x, y, z) in km (customize as desired)
sphere_center = (3000, 5000, 1000)
sphere_radius = 4000  # Sphere radius in km (customize as desired)

plot_sphere_intersecting_earth(sphere_center, sphere_radius)

# %%
import folium
from proj4leaflet import Proj4Leaflet

# Create a map
m = folium.Map(location=[0, 0], zoom_start=1)

# Set the projection to orthographic
proj4 = Proj4Leaflet(init='EPSG:3857')
m.set_crs(proj4)

# Add a layer with the coastlines of the world
folium.TileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png',
  attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a>',
).add_to(m)

# Add a layer with the data for the coastlines
folium.GeoJson(data, style_function=lambda feature: {
    'color': 'black',
    'width': 1,
}).add_to(m)

# Display the map
m.save('map.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import folium
# ----> 2 from proj4leaflet import Proj4Leaflet
#       4 # Create a map
#       5 m = folium.Map(location=[0, 0], zoom_start=1)
#
# ModuleNotFoundError: No module named 'proj4leaflet'

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
# lon_0, lat_0 are the center point of the projection.
# resolution = 'l' means use low resolution coastlines.
m = Basemap(projection='ortho',lon_0=-105,lat_0=40,resolution='l')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
# draw parallels and meridians.
m.drawparallels(np.arange(-90.,120.,30.))
m.drawmeridians(np.arange(0.,420.,60.))
m.drawmapboundary(fill_color='aqua') 
plt.title("Full Disk Orthographic Projection")
plt.show()

# %%
from math import atan2, cos, sin, sqrt, radians

def calculate_initial_bearing(lat1, lon1, lat2, lon2):
    """
    Calculate the initial bearing (forward azimuth) between two points on the Earth's surface
    using Vincenty inverse formula.

    :param lat1: Latitude of the starting location in degrees
    :param lon1: Longitude of the starting location in degrees
    :param lat2: Latitude of the ending location in degrees
    :param lon2: Longitude of the ending location in degrees
    :return: Initial bearing in degrees (0° <= bearing < 360°)
    """

    # Convert latitude and longitude from degrees to radians
    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    # Vincenty formula parameters
    a = 6378137.0  # Semi-major axis of the WGS84 ellipsoid (meters)
    f = 1/298.257223563  # Flattening of the WGS84 ellipsoid

    # Calculate differences in longitude
    delta_lon = lon2 - lon1

    # Calculate the reduced latitude (reduced to the equator)
    U1 = atan2((1 - f) * sin(lat1), cos(lat1))
    U2 = atan2((1 - f) * sin(lat2), cos(lat2))

    # Calculate the initial bearing
    L = delta_lon
    sin_sigma = sqrt((cos(U2) * sin(L))**2 + (cos(U1) * sin(U2) - sin(U1) * cos(U2) * cos(L))**2)
    cos_sigma = sin(U1) * sin(U2) + cos(U1) * cos(U2) * cos(L)
    sigma = atan2(sin_sigma, cos_sigma)
    alpha = atan2(cos(U1) * cos(U2) * sin(L), sin(U2) * cos(U1) - cos(U2) * sin(U1) * cos(L))
    
    # Calculate the initial bearing in degrees
    initial_bearing = (alpha * 180.0) / 3.141592653589793

    # Normalize the bearing to the range [0, 360)
    initial_bearing = (initial_bearing + 360) % 360

    return initial_bearing

# Example usage:
start_latitude = 30.03415  # San Francisco, CA
start_longitude = -110.89016
end_latitude = 40.7127753  # Los Angeles, CA
end_longitude = -74.0059728

bearing = calculate_initial_bearing(start_latitude, start_longitude, end_latitude, end_longitude)
print(f"Accurate Bearing from San Francisco to Los Angeles: {bearing:.2f} degrees")
# Out:
# Accurate Bearing from San Francisco to Los Angeles: 56.53 degrees

# %%
# Define the coordinates
start_latitude = 30.03415
start_longitude = -110.89016
end_latitude = 40.71277
end_longitude = -74.00598

# Calculate the bearing
bearing = calculate_initial_bearing(start_latitude, start_longitude, end_latitude, end_longitude)

print(f"Bearing from (30.03415, -110.89016) to (40.71277, -74.00598): {bearing:.2f} degrees")
# Out:
# Bearing from (30.03415, -110.89016) to (40.71277, -74.00598): 56.53 degrees

# %%
from geographiclib.geodesic import Geodesic

def calculate_initial_bearing(lat1, lon1, lat2, lon2):
    """
    Calculate the initial bearing (forward azimuth) between two points on the Earth's surface
    using GeographicLib.

    :param lat1: Latitude of the starting location in degrees
    :param lon1: Longitude of the starting location in degrees
    :param lat2: Latitude of the ending location in degrees
    :param lon2: Longitude of the ending location in degrees
    :return: Initial bearing in degrees (0° <= bearing < 360°)
    """
    
    geod = Geodesic.WGS84.Inverse(lat1, lon1, lat2, lon2)
    initial_bearing = geod['azi1']

    # Normalize the bearing to the range [0, 360)
    initial_bearing = (initial_bearing + 360) % 360
    
    return initial_bearing

# Example usage:
start_latitude = 45.54548
start_longitude = 11.53541
end_latitude = -33.8688197
end_longitude = 151.2092955

bearing = calculate_initial_bearing(start_latitude, start_longitude, end_latitude, end_longitude)
print(f"Accurate Bearing from (30.03415, -110.89016) to (40.71277, -74.00598): {bearing:.2f} degrees")
# Out:
# Accurate Bearing from (30.03415, -110.89016) to (40.71277, -74.00598): 83.19 degrees

# %%
import sys
sys.path.append('../apps')  # Replace with the actual path
import z_functions as zf

zf.P2P(45.54548, 11.53541,-33.86882, 151.20929)
# Out:
# [83.18686371392901, 123.06323619724074, 16372398.755053096]

# %%
import pygeodesy.sphericalNvector as sv
import pygeodesy. as eb



s = sv.LatLon(45.54548, 11.53541)
e = sv.LatLon(-33.8688197, 151.2092955)

eb.initialBearingTo(s, e)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 9
#       6 s = sv.LatLon(45.54548, 11.53541)
#       7 e = sv.LatLon(-33.8688197, 151.2092955)
# ----> 9 eb.initialBearingTo(s, e)
#
# AttributeError: module 'pygeodesy.ellipsoidalBaseDI' has no attribute 'initialBearingTo'

# %%
from pygeodesy import ellipsoidalVincenty as ev


# Define the coordinates
start_point = ev.LatLon(45.54548, 11.53541)
end_point = ev.LatLon(-33.8688197, 151.2092955)

# Calculate the initial bearing
bearing = start_point.initialBearingTo(end_point)


print(f"Bearing from (30.03415, -110.89016) to (40.71277, -74.00598): {bearing:.2f} degrees")
# Out:
# Bearing from (30.03415, -110.89016) to (40.71277, -74.00598): 83.19 degrees

# %%
from pygeodesy import ellipsoidalVincenty as ev

# Define the coordinates of the two points
point1 = ev.LatLon(45.54548, 11.53541)  # San Francisco, CA
point2 = ev.LatLon(-33.8688197, 151.2092955)  # Los Angeles, CA

# %%
# Calculate the 3D distance
distance = point1.distanceTo3(point2)
distance[1]
# Out:
# 83.18685860606146

# %%
print(f"3D Distance from San Francisco to Los Angeles: {distance:.2f} meters")
